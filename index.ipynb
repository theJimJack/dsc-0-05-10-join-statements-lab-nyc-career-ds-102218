# %% [markdown]
# # Join Statements

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on Join statements.

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table we will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, we'll use the same Customer Relationship Management (CRM) database we used in our lecture before!
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.

# %%
cur.execute("""select firstName, lastName , city from employees e
                JOIN offices o
                ON e.officeCode = o.officeCode
                WHERE city = 'Boston';""")
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#   firstName   lastName    city
# 0     Julie   Firrelli  Boston
# 1     Steve  Patterson  Boston

# %% [markdown]
# ## Do any offices have no employees?

# %%
cur.execute("""SELECT city FROM offices o
                ;""").fetchall()
# Out:
# [('San Francisco',),
#  ('Boston',),
#  ('NYC',),
#  ('Paris',),
#  ('Tokyo',),
#  ('Sydney',),
#  ('London',)]

# %%
cur.execute("""SELECT city,count(lastName) FROM employees e
                JOIN offices o
                ON e.officeCode = o.officeCode
                ;""").fetchall()
# df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
# df.columns = [i[0] for i in cur.description]
# df.head()
# Out:
# [('Paris', 23)]

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold.

# %%
cur.execute("""select lastName, firstName, productName from products p
                JOIN orderdetails od
                ON p.productcode = od.productcode
                JOIN orders o
                ON od.orderNumber = o.orderNumber
                JOIN customers c
                ON o.customerNumber = c.customerNumber
                JOIN employees e
                ON c.salesRepEmployeeNumber = e.employeeNumber
                ORDER BY lastName;""").fetchall()
# df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
# df.columns = [i[0] for i in cur.description]
# df.head()
# Out:
# [('Bondur', 'Loui', '1969 Harley Davidson Ultimate Chopper'),
#  ('Bondur', 'Loui', '1969 Harley Davidson Ultimate Chopper'),
#  ('Bondur', 'Loui', '1969 Harley Davidson Ultimate Chopper'),
#  ('Bondur', 'Loui', '1952 Alpine Renault 1300'),
#  ('Bondur', 'Loui', '1996 Moto Guzzi 1100i'),
#  ('Bondur', 'Loui', '1996 Moto Guzzi 1100i'),
#  ('Bondur', 'Loui', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Bondur', 'Loui', '1972 Alfa Romeo GTA'),
#  ('Bondur', 'Loui', '1972 Alfa Romeo GTA'),
#  ('Bondur', 'Loui', '1962 LanciaA Delta 16V'),
#  ('Bondur', 'Loui', '1962 LanciaA Delta 16V'),
#  ('Bondur', 'Loui', '1968 Ford Mustang'),
#  ('Bondur', 'Loui', '1968 Ford Mustang'),
#  ('Bondur', 'Loui', '2001 Ferrari Enzo'),
#  ('Bondur', 'Loui', '2001 Ferrari Enzo'),
#  ('Bondur', 'Loui', '2001 Ferrari Enzo'),
#  ('Bondur', 'Loui', '2001 Ferrari Enzo'),
#  ('Bondur', 'Loui', '1958 Setra Bus'),
#  ('Bondur', 'Loui', '2002 Suzuki XREO'),
#  ('Bondur', 'Loui', '2002 Suzuki XREO'),
#  ('Bondur', 'Loui', '2002 Suzuki XREO'),
#  ('Bondur', 'Loui', '1969 Corvair Monza'),
#  ('Bondur', 'Loui', '1969 Corvair Monza'),
#  ('Bondur', 'Loui', '1968 Dodge Charger'),
#  ('Bondur', 'Loui', '1969 Ford Falcon'),
#  ('Bondur', 'Loui', '1969 Ford Falcon'),
#  ('Bondur', 'Loui', '1969 Ford Falcon'),
#  ('Bondur', 'Loui', '1970 Plymouth Hemi Cuda'),
#  ('Bondur', 'Loui', '1970 Plymouth Hemi Cuda'),
#  ('Bondur', 'Loui', '1957 Chevy Pickup'),
#  ('Bondur', 'Loui', '1969 Dodge Charger'),
#  ('Bondur', 'Loui', '1940 Ford Pickup Truck'),
#  ('Bondur', 'Loui', '1993 Mazda RX-7'),
#  ('Bondur', 'Loui', '1993 Mazda RX-7'),
#  ('Bondur', 'Loui', '1937 Lincoln Berline'),
#  ('Bondur', 'Loui', '1937 Lincoln Berline'),
#  ('Bondur', 'Loui', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Bondur', 'Loui', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Bondur', 'Loui', '1965 Aston Martin DB5'),
#  ('Bondur', 'Loui', '1965 Aston Martin DB5'),
#  ('Bondur', 'Loui', '1980s Black Hawk Helicopter'),
#  ('Bondur', 'Loui', '1917 Grand Touring Sedan'),
#  ('Bondur', 'Loui', '1917 Grand Touring Sedan'),
#  ('Bondur', 'Loui', '1948 Porsche 356-A Roadster'),
#  ('Bondur', 'Loui', '1995 Honda Civic'),
#  ('Bondur', 'Loui', '1995 Honda Civic'),
#  ('Bondur', 'Loui', '1998 Chrysler Plymouth Prowler'),
#  ('Bondur', 'Loui', '1911 Ford Town Car'),
#  ('Bondur', 'Loui', '1911 Ford Town Car'),
#  ('Bondur', 'Loui', '1964 Mercedes Tour Bus'),
#  ('Bondur', 'Loui', '1932 Model A Ford J-Coupe'),
#  ('Bondur', 'Loui', '1932 Model A Ford J-Coupe'),
#  ('Bondur', 'Loui', '1932 Model A Ford J-Coupe'),
#  ('Bondur', 'Loui', '1926 Ford Fire Engine'),
#  ('Bondur', 'Loui', '1926 Ford Fire Engine'),
#  ('Bondur', 'Loui', 'P-51-D Mustang'),
#  ('Bondur', 'Loui', '1936 Harley Davidson El Knucklehead'),
#  ('Bondur', 'Loui', '1936 Harley Davidson El Knucklehead'),
#  ('Bondur', 'Loui', '1928 Mercedes-Benz SSK'),
#  ('Bondur', 'Loui', '1928 Mercedes-Benz SSK'),
#  ('Bondur', 'Loui', '1999 Indy 500 Monte Carlo SS'),
#  ('Bondur', 'Loui', '1999 Indy 500 Monte Carlo SS'),
#  ('Bondur', 'Loui', '1999 Yamaha Speed Boat'),
#  ('Bondur', 'Loui', '1903 Ford Model A'),
#  ('Bondur', 'Loui', '1903 Ford Model A'),
#  ('Bondur', 'Loui', '1992 Ferrari 360 Spider red'),
#  ('Bondur', 'Loui', '1992 Ferrari 360 Spider red'),
#  ('Bondur', 'Loui', 'Collectable Wooden Train'),
#  ('Bondur', 'Loui', 'Collectable Wooden Train'),
#  ('Bondur', 'Loui', '1969 Dodge Super Bee'),
#  ('Bondur', 'Loui', '1969 Dodge Super Bee'),
#  ('Bondur', 'Loui', '1969 Dodge Super Bee'),
#  ('Bondur', 'Loui', '1917 Maxwell Touring Car'),
#  ('Bondur', 'Loui', '1976 Ford Gran Torino'),
#  ('Bondur', 'Loui', '1976 Ford Gran Torino'),
#  ('Bondur', 'Loui', '1976 Ford Gran Torino'),
#  ('Bondur', 'Loui', '1948 Porsche Type 356 Roadster'),
#  ('Bondur', 'Loui', '1948 Porsche Type 356 Roadster'),
#  ('Bondur', 'Loui', '1957 Vespa GS150'),
#  ('Bondur', 'Loui', '1957 Vespa GS150'),
#  ('Bondur', 'Loui', '1957 Vespa GS150'),
#  ('Bondur', 'Loui', '1957 Vespa GS150'),
#  ('Bondur', 'Loui', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Bondur', 'Loui', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Bondur', 'Loui', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Bondur', 'Loui', '1904 Buick Runabout'),
#  ('Bondur', 'Loui', '1940s Ford truck'),
#  ('Bondur', 'Loui', '1940s Ford truck'),
#  ('Bondur', 'Loui', '1939 Cadillac Limousine'),
#  ('Bondur', 'Loui', '1957 Corvette Convertible'),
#  ('Bondur', 'Loui', '1957 Corvette Convertible'),
#  ('Bondur', 'Loui', '1957 Corvette Convertible'),
#  ('Bondur', 'Loui', '1957 Ford Thunderbird'),
#  ('Bondur', 'Loui', '1957 Ford Thunderbird'),
#  ('Bondur', 'Loui', '1970 Chevy Chevelle SS 454'),
#  ('Bondur', 'Loui', '1970 Dodge Coronet'),
#  ('Bondur', 'Loui', '1997 BMW R 1100 S'),
#  ('Bondur', 'Loui', '1997 BMW R 1100 S'),
#  ('Bondur', 'Loui', '1966 Shelby Cobra 427 S/C'),
#  ('Bondur', 'Loui', '1966 Shelby Cobra 427 S/C'),
#  ('Bondur', 'Loui', '1928 British Royal Navy Airplane'),
#  ('Bondur', 'Loui', '1939 Chevrolet Deluxe Coupe'),
#  ('Bondur', 'Loui', '1939 Chevrolet Deluxe Coupe'),
#  ('Bondur', 'Loui', '1939 Chevrolet Deluxe Coupe'),
#  ('Bondur', 'Loui', '1960 BSA Gold Star DBD34'),
#  ('Bondur', 'Loui', '1960 BSA Gold Star DBD34'),
#  ('Bondur', 'Loui', '18th century schooner'),
#  ('Bondur', 'Loui', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Bondur', 'Loui', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Bondur', 'Loui', '1962 Volkswagen Microbus'),
#  ('Bondur', 'Loui', '1962 Volkswagen Microbus'),
#  ('Bondur', 'Loui', '1982 Ducati 900 Monster'),
#  ('Bondur', 'Loui', '1982 Ducati 900 Monster'),
#  ('Bondur', 'Loui', '1982 Ducati 900 Monster'),
#  ('Bondur', 'Loui', '1949 Jaguar XK 120'),
#  ('Bondur', 'Loui', '1958 Chevy Corvette Limited Edition'),
#  ('Bondur', 'Loui', '1900s Vintage Bi-Plane'),
#  ('Bondur', 'Loui', '1952 Citroen-15CV'),
#  ('Bondur', 'Loui', '1982 Lamborghini Diablo'),
#  ('Bondur', 'Loui', '1912 Ford Model T Delivery Wagon'),
#  ('Bondur', 'Loui', '1969 Chevrolet Camaro Z28'),
#  ('Bondur', 'Loui', '1971 Alpine Renault 1600s'),
#  ('Bondur', 'Loui', '1971 Alpine Renault 1600s'),
#  ('Bondur', 'Loui', '1937 Horch 930V Limousine'),
#  ('Bondur', 'Loui', '1956 Porsche 356A Coupe'),
#  ('Bondur', 'Loui', 'Corsair F4U ( Bird Cage)'),
#  ('Bondur', 'Loui', '1936 Mercedes Benz 500k Roadster'),
#  ('Bondur', 'Loui', '1992 Porsche Cayenne Turbo Silver'),
#  ('Bondur', 'Loui', '1992 Porsche Cayenne Turbo Silver'),
#  ('Bondur', 'Loui', '1900s Vintage Tri-Plane'),
#  ('Bondur', 'Loui', '1961 Chevrolet Impala'),
#  ('Bondur', 'Loui', '1961 Chevrolet Impala'),
#  ('Bondur', 'Loui', '1961 Chevrolet Impala'),
#  ('Bondur', 'Loui', '1961 Chevrolet Impala'),
#  ('Bondur', 'Loui', '1980’s GM Manhattan Express'),
#  ('Bondur', 'Loui', '1980’s GM Manhattan Express'),
#  ('Bondur', 'Loui', '1982 Ducati 996 R'),
#  ('Bondur', 'Loui', '1982 Ducati 996 R'),
#  ('Bondur', 'Loui', '1982 Ducati 996 R'),
#  ('Bondur', 'Loui', '1982 Ducati 996 R'),
#  ('Bondur', 'Loui', '1982 Ducati 996 R'),
#  ('Bondur', 'Loui', '1954 Greyhound Scenicruiser'),
#  ('Bondur', 'Loui', '1954 Greyhound Scenicruiser'),
#  ('Bondur', 'Loui', "1950's Chicago Surface Lines Streetcar"),
#  ('Bondur', 'Loui', "1950's Chicago Surface Lines Streetcar"),
#  ('Bondur', 'Loui', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Bondur', 'Loui', '1928 Ford Phaeton Deluxe'),
#  ('Bondur', 'Loui', '1974 Ducati 350 Mk3 Desmo'),
#  ('Bondur', 'Loui', '1974 Ducati 350 Mk3 Desmo'),
#  ('Bondur', 'Loui', '1974 Ducati 350 Mk3 Desmo'),
#  ('Bondur', 'Loui', '1930 Buick Marquette Phaeton'),
#  ('Bondur', 'Loui', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Bondur', 'Loui', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Bondur', 'Loui', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Bondur', 'Loui', '1962 City of Detroit Streetcar'),
#  ('Bondur', 'Loui', '1962 City of Detroit Streetcar'),
#  ('Bondur', 'Loui', '1962 City of Detroit Streetcar'),
#  ('Bondur', 'Loui', '2002 Yamaha YZR M1'),
#  ('Bondur', 'Loui', '2002 Yamaha YZR M1'),
#  ('Bondur', 'Loui', '2002 Yamaha YZR M1'),
#  ('Bondur', 'Loui', '2002 Yamaha YZR M1'),
#  ('Bondur', 'Loui', 'The Schooner Bluenose'),
#  ('Bondur', 'Loui', 'American Airlines: B767-300'),
#  ('Bondur', 'Loui', 'The Mayflower'),
#  ('Bondur', 'Loui', 'HMS Bounty'),
#  ('Bondur', 'Loui', 'America West Airlines B757-200'),
#  ('Bondur', 'Loui', 'The USS Constitution Ship'),
#  ('Bondur', 'Loui', '1982 Camaro Z28'),
#  ('Bondur', 'Loui', '1982 Camaro Z28'),
#  ('Bondur', 'Loui', '1982 Camaro Z28'),
#  ('Bondur', 'Loui', 'ATA: B757-300'),
#  ('Bondur', 'Loui', 'F/A 18 Hornet 1/72'),
#  ('Bondur', 'Loui', 'The Titanic'),
#  ('Bondur', 'Loui', 'The Queen Mary'),
#  ('Bondur', 'Loui', 'American Airlines: MD-11S'),
#  ('Bondur', 'Loui', 'Boeing X-32A JSF'),
#  ('Bondur', 'Loui', 'Pont Yacht'),
#  ('Bott', 'Larry', '1969 Harley Davidson Ultimate Chopper'),
#  ('Bott', 'Larry', '1969 Harley Davidson Ultimate Chopper'),
#  ('Bott', 'Larry', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Bott', 'Larry', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Bott', 'Larry', '1972 Alfa Romeo GTA'),
#  ('Bott', 'Larry', '1972 Alfa Romeo GTA'),
#  ('Bott', 'Larry', '1972 Alfa Romeo GTA'),
#  ('Bott', 'Larry', '1972 Alfa Romeo GTA'),
#  ('Bott', 'Larry', '1972 Alfa Romeo GTA'),
#  ('Bott', 'Larry', '1962 LanciaA Delta 16V'),
#  ('Bott', 'Larry', '1968 Ford Mustang'),
#  ('Bott', 'Larry', '1968 Ford Mustang'),
#  ('Bott', 'Larry', '2001 Ferrari Enzo'),
#  ('Bott', 'Larry', '2001 Ferrari Enzo'),
#  ('Bott', 'Larry', '2002 Suzuki XREO'),
#  ('Bott', 'Larry', '2002 Suzuki XREO'),
#  ('Bott', 'Larry', '1969 Corvair Monza'),
#  ('Bott', 'Larry', '1969 Corvair Monza'),
#  ('Bott', 'Larry', '1968 Dodge Charger'),
#  ('Bott', 'Larry', '1968 Dodge Charger'),
#  ('Bott', 'Larry', '1969 Ford Falcon'),
#  ('Bott', 'Larry', '1969 Ford Falcon'),
#  ('Bott', 'Larry', '1970 Plymouth Hemi Cuda'),
#  ('Bott', 'Larry', '1970 Plymouth Hemi Cuda'),
#  ('Bott', 'Larry', '1970 Plymouth Hemi Cuda'),
#  ('Bott', 'Larry', '1957 Chevy Pickup'),
#  ('Bott', 'Larry', '1957 Chevy Pickup'),
#  ('Bott', 'Larry', '1957 Chevy Pickup'),
#  ('Bott', 'Larry', '1969 Dodge Charger'),
#  ('Bott', 'Larry', '1969 Dodge Charger'),
#  ('Bott', 'Larry', '1969 Dodge Charger'),
#  ('Bott', 'Larry', '1969 Dodge Charger'),
#  ('Bott', 'Larry', '1993 Mazda RX-7'),
#  ('Bott', 'Larry', '1993 Mazda RX-7'),
#  ('Bott', 'Larry', '1937 Lincoln Berline'),
#  ('Bott', 'Larry', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Bott', 'Larry', '1965 Aston Martin DB5'),
#  ('Bott', 'Larry', '1965 Aston Martin DB5'),
#  ('Bott', 'Larry', '1980s Black Hawk Helicopter'),
#  ('Bott', 'Larry', '1980s Black Hawk Helicopter'),
#  ('Bott', 'Larry', '1980s Black Hawk Helicopter'),
#  ('Bott', 'Larry', '1980s Black Hawk Helicopter'),
#  ('Bott', 'Larry', '1980s Black Hawk Helicopter'),
#  ('Bott', 'Larry', '1917 Grand Touring Sedan'),
#  ('Bott', 'Larry', '1917 Grand Touring Sedan'),
#  ('Bott', 'Larry', '1948 Porsche 356-A Roadster'),
#  ('Bott', 'Larry', '1948 Porsche 356-A Roadster'),
#  ('Bott', 'Larry', '1948 Porsche 356-A Roadster'),
#  ('Bott', 'Larry', '1948 Porsche 356-A Roadster'),
#  ('Bott', 'Larry', '1995 Honda Civic'),
#  ('Bott', 'Larry', '1995 Honda Civic'),
#  ('Bott', 'Larry', '1998 Chrysler Plymouth Prowler'),
#  ('Bott', 'Larry', '1998 Chrysler Plymouth Prowler'),
#  ('Bott', 'Larry', '1911 Ford Town Car'),
#  ('Bott', 'Larry', '1911 Ford Town Car'),
#  ('Bott', 'Larry', '1964 Mercedes Tour Bus'),
#  ('Bott', 'Larry', '1964 Mercedes Tour Bus'),
#  ('Bott', 'Larry', '1964 Mercedes Tour Bus'),
#  ('Bott', 'Larry', '1932 Model A Ford J-Coupe'),
#  ('Bott', 'Larry', '1932 Model A Ford J-Coupe'),
#  ('Bott', 'Larry', '1926 Ford Fire Engine'),
#  ('Bott', 'Larry', '1926 Ford Fire Engine'),
#  ('Bott', 'Larry', '1928 Mercedes-Benz SSK'),
#  ('Bott', 'Larry', '1928 Mercedes-Benz SSK'),
#  ('Bott', 'Larry', '1999 Indy 500 Monte Carlo SS'),
#  ('Bott', 'Larry', '1934 Ford V8 Coupe'),
#  ('Bott', 'Larry', '1999 Yamaha Speed Boat'),
#  ('Bott', 'Larry', '1999 Yamaha Speed Boat'),
#  ('Bott', 'Larry', '1999 Yamaha Speed Boat'),
#  ('Bott', 'Larry', '1999 Yamaha Speed Boat'),
#  ('Bott', 'Larry', '18th Century Vintage Horse Carriage'),
#  ('Bott', 'Larry', '1903 Ford Model A'),
#  ('Bott', 'Larry', '1903 Ford Model A'),
#  ('Bott', 'Larry', '1992 Ferrari 360 Spider red'),
#  ('Bott', 'Larry', '1992 Ferrari 360 Spider red'),
#  ('Bott', 'Larry', '1992 Ferrari 360 Spider red'),
#  ('Bott', 'Larry', '1992 Ferrari 360 Spider red'),
#  ('Bott', 'Larry', '1992 Ferrari 360 Spider red'),
#  ('Bott', 'Larry', '1992 Ferrari 360 Spider red'),
#  ('Bott', 'Larry', 'Collectable Wooden Train'),
#  ('Bott', 'Larry', 'Collectable Wooden Train'),
#  ('Bott', 'Larry', '1969 Dodge Super Bee'),
#  ('Bott', 'Larry', '1976 Ford Gran Torino'),
#  ('Bott', 'Larry', '1948 Porsche Type 356 Roadster'),
#  ('Bott', 'Larry', '1957 Vespa GS150'),
#  ('Bott', 'Larry', '1957 Vespa GS150'),
#  ('Bott', 'Larry', '1957 Vespa GS150'),
#  ('Bott', 'Larry', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Bott', 'Larry', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Bott', 'Larry', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Bott', 'Larry', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Bott', 'Larry', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Bott', 'Larry', '1970 Triumph Spitfire'),
#  ('Bott', 'Larry', '1970 Triumph Spitfire'),
#  ('Bott', 'Larry', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Bott', 'Larry', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Bott', 'Larry', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Bott', 'Larry', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Bott', 'Larry', '1904 Buick Runabout'),
#  ('Bott', 'Larry', '1904 Buick Runabout'),
#  ('Bott', 'Larry', '1940s Ford truck'),
#  ('Bott', 'Larry', '1957 Corvette Convertible'),
#  ('Bott', 'Larry', '1957 Corvette Convertible'),
#  ('Bott', 'Larry', '1957 Ford Thunderbird'),
#  ('Bott', 'Larry', '1957 Ford Thunderbird'),
#  ('Bott', 'Larry', '1957 Ford Thunderbird'),
#  ('Bott', 'Larry', '1957 Ford Thunderbird'),
#  ('Bott', 'Larry', '1970 Chevy Chevelle SS 454'),
#  ('Bott', 'Larry', '1970 Chevy Chevelle SS 454'),
#  ('Bott', 'Larry', '1970 Dodge Coronet'),
#  ('Bott', 'Larry', '1997 BMW R 1100 S'),
#  ('Bott', 'Larry', '1997 BMW R 1100 S'),
#  ('Bott', 'Larry', '1966 Shelby Cobra 427 S/C'),
#  ('Bott', 'Larry', '1966 Shelby Cobra 427 S/C'),
#  ('Bott', 'Larry', '1928 British Royal Navy Airplane'),
#  ('Bott', 'Larry', '1939 Chevrolet Deluxe Coupe'),
#  ('Bott', 'Larry', '1939 Chevrolet Deluxe Coupe'),
#  ('Bott', 'Larry', '1960 BSA Gold Star DBD34'),
#  ('Bott', 'Larry', '18th century schooner'),
#  ('Bott', 'Larry', '18th century schooner'),
#  ('Bott', 'Larry', '18th century schooner'),
#  ('Bott', 'Larry', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Bott', 'Larry', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Bott', 'Larry', '1962 Volkswagen Microbus'),
#  ('Bott', 'Larry', '1962 Volkswagen Microbus'),
#  ('Bott', 'Larry', '1982 Ducati 900 Monster'),
#  ('Bott', 'Larry', '1982 Ducati 900 Monster'),
#  ('Bott', 'Larry', '1982 Ducati 900 Monster'),
#  ('Bott', 'Larry', '1949 Jaguar XK 120'),
#  ('Bott', 'Larry', '1949 Jaguar XK 120'),
#  ('Bott', 'Larry', '1949 Jaguar XK 120'),
#  ('Bott', 'Larry', '1958 Chevy Corvette Limited Edition'),
#  ('Bott', 'Larry', '1958 Chevy Corvette Limited Edition'),
#  ('Bott', 'Larry', '1958 Chevy Corvette Limited Edition'),
#  ('Bott', 'Larry', '1900s Vintage Bi-Plane'),
#  ('Bott', 'Larry', '1900s Vintage Bi-Plane'),
#  ('Bott', 'Larry', '1900s Vintage Bi-Plane'),
#  ('Bott', 'Larry', '1900s Vintage Bi-Plane'),
#  ('Bott', 'Larry', '1900s Vintage Bi-Plane'),
#  ('Bott', 'Larry', '1952 Citroen-15CV'),
#  ('Bott', 'Larry', '1952 Citroen-15CV'),
#  ('Bott', 'Larry', '1952 Citroen-15CV'),
#  ('Bott', 'Larry', '1952 Citroen-15CV'),
#  ('Bott', 'Larry', '1982 Lamborghini Diablo'),
#  ('Bott', 'Larry', '1982 Lamborghini Diablo'),
#  ('Bott', 'Larry', '1912 Ford Model T Delivery Wagon'),
#  ('Bott', 'Larry', '1912 Ford Model T Delivery Wagon'),
#  ('Bott', 'Larry', '1912 Ford Model T Delivery Wagon'),
#  ('Bott', 'Larry', '1969 Chevrolet Camaro Z28'),
#  ('Bott', 'Larry', '1969 Chevrolet Camaro Z28'),
#  ('Bott', 'Larry', '1969 Chevrolet Camaro Z28'),
#  ('Bott', 'Larry', '1971 Alpine Renault 1600s'),
#  ('Bott', 'Larry', '1971 Alpine Renault 1600s'),
#  ('Bott', 'Larry', '1937 Horch 930V Limousine'),
#  ('Bott', 'Larry', '1937 Horch 930V Limousine'),
#  ('Bott', 'Larry', '1937 Horch 930V Limousine'),
#  ('Bott', 'Larry', '1937 Horch 930V Limousine'),
#  ('Bott', 'Larry', '1937 Horch 930V Limousine'),
#  ('Bott', 'Larry', '2002 Chevy Corvette'),
#  ('Bott', 'Larry', '2002 Chevy Corvette'),
#  ('Bott', 'Larry', '1940 Ford Delivery Sedan'),
#  ('Bott', 'Larry', '1940 Ford Delivery Sedan'),
#  ('Bott', 'Larry', '1940 Ford Delivery Sedan'),
#  ('Bott', 'Larry', '1940 Ford Delivery Sedan'),
#  ('Bott', 'Larry', '1940 Ford Delivery Sedan'),
#  ('Bott', 'Larry', '1956 Porsche 356A Coupe'),
#  ('Bott', 'Larry', '1956 Porsche 356A Coupe'),
#  ('Bott', 'Larry', '1956 Porsche 356A Coupe'),
#  ('Bott', 'Larry', 'Corsair F4U ( Bird Cage)'),
#  ('Bott', 'Larry', 'Corsair F4U ( Bird Cage)'),
#  ('Bott', 'Larry', 'Corsair F4U ( Bird Cage)'),
#  ('Bott', 'Larry', 'Corsair F4U ( Bird Cage)'),
#  ('Bott', 'Larry', '1936 Mercedes Benz 500k Roadster'),
#  ('Bott', 'Larry', '1936 Mercedes Benz 500k Roadster'),
#  ('Bott', 'Larry', '1992 Porsche Cayenne Turbo Silver'),
#  ('Bott', 'Larry', '1961 Chevrolet Impala'),
#  ('Bott', 'Larry', '1961 Chevrolet Impala'),
#  ('Bott', 'Larry', '1980’s GM Manhattan Express'),
#  ('Bott', 'Larry', '1980’s GM Manhattan Express'),
#  ('Bott', 'Larry', '1997 BMW F650 ST'),
#  ('Bott', 'Larry', '1982 Ducati 996 R'),
#  ('Bott', 'Larry', '1982 Ducati 996 R'),
#  ('Bott', 'Larry', '1954 Greyhound Scenicruiser'),
#  ('Bott', 'Larry', '1954 Greyhound Scenicruiser'),
#  ('Bott', 'Larry', '1954 Greyhound Scenicruiser'),
#  ('Bott', 'Larry', "1950's Chicago Surface Lines Streetcar"),
#  ('Bott', 'Larry', "1950's Chicago Surface Lines Streetcar"),
#  ('Bott', 'Larry', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Bott', 'Larry', '1928 Ford Phaeton Deluxe'),
#  ('Bott', 'Larry', '1974 Ducati 350 Mk3 Desmo'),
#  ('Bott', 'Larry', '1974 Ducati 350 Mk3 Desmo'),
#  ('Bott', 'Larry', '1930 Buick Marquette Phaeton'),
#  ('Bott', 'Larry', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Bott', 'Larry', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Bott', 'Larry', '1962 City of Detroit Streetcar'),
#  ('Bott', 'Larry', '1962 City of Detroit Streetcar'),
#  ('Bott', 'Larry', '2002 Yamaha YZR M1'),
#  ('Bott', 'Larry', '2002 Yamaha YZR M1'),
#  ('Bott', 'Larry', 'The Schooner Bluenose'),
#  ('Bott', 'Larry', 'The Schooner Bluenose'),
#  ('Bott', 'Larry', 'The Schooner Bluenose'),
#  ('Bott', 'Larry', 'American Airlines: B767-300'),
#  ('Bott', 'Larry', 'The Mayflower'),
#  ('Bott', 'Larry', 'The Mayflower'),
#  ('Bott', 'Larry', 'HMS Bounty'),
#  ('Bott', 'Larry', 'HMS Bounty'),
#  ('Bott', 'Larry', 'HMS Bounty'),
#  ('Bott', 'Larry', 'HMS Bounty'),
#  ('Bott', 'Larry', 'America West Airlines B757-200'),
#  ('Bott', 'Larry', 'America West Airlines B757-200'),
#  ('Bott', 'Larry', 'The USS Constitution Ship'),
#  ('Bott', 'Larry', 'The USS Constitution Ship'),
#  ('Bott', 'Larry', 'The USS Constitution Ship'),
#  ('Bott', 'Larry', 'The USS Constitution Ship'),
#  ('Bott', 'Larry', '1982 Camaro Z28'),
#  ('Bott', 'Larry', 'F/A 18 Hornet 1/72'),
#  ('Bott', 'Larry', 'F/A 18 Hornet 1/72'),
#  ('Bott', 'Larry', 'The Titanic'),
#  ('Bott', 'Larry', 'The Titanic'),
#  ('Bott', 'Larry', 'The Titanic'),
#  ('Bott', 'Larry', 'The Titanic'),
#  ('Bott', 'Larry', 'The Queen Mary'),
#  ('Bott', 'Larry', 'The Queen Mary'),
#  ('Bott', 'Larry', 'The Queen Mary'),
#  ('Bott', 'Larry', 'The Queen Mary'),
#  ('Bott', 'Larry', 'American Airlines: MD-11S'),
#  ('Bott', 'Larry', 'American Airlines: MD-11S'),
#  ('Bott', 'Larry', 'American Airlines: MD-11S'),
#  ('Bott', 'Larry', 'Boeing X-32A JSF'),
#  ('Bott', 'Larry', 'Boeing X-32A JSF'),
#  ('Bott', 'Larry', 'Boeing X-32A JSF'),
#  ('Bott', 'Larry', 'Boeing X-32A JSF'),
#  ('Bott', 'Larry', 'Pont Yacht'),
#  ('Bott', 'Larry', 'Pont Yacht'),
#  ('Bott', 'Larry', 'Pont Yacht'),
#  ('Bott', 'Larry', 'Pont Yacht'),
#  ('Castillo', 'Pamela', '1969 Harley Davidson Ultimate Chopper'),
#  ('Castillo', 'Pamela', '1952 Alpine Renault 1300'),
#  ('Castillo', 'Pamela', '1972 Alfa Romeo GTA'),
#  ('Castillo', 'Pamela', '1972 Alfa Romeo GTA'),
#  ('Castillo', 'Pamela', '1972 Alfa Romeo GTA'),
#  ('Castillo', 'Pamela', '1962 LanciaA Delta 16V'),
#  ('Castillo', 'Pamela', '1968 Ford Mustang'),
#  ('Castillo', 'Pamela', '1968 Ford Mustang'),
#  ('Castillo', 'Pamela', '1968 Ford Mustang'),
#  ('Castillo', 'Pamela', '1968 Ford Mustang'),
#  ('Castillo', 'Pamela', '2001 Ferrari Enzo'),
#  ('Castillo', 'Pamela', '2001 Ferrari Enzo'),
#  ('Castillo', 'Pamela', '2001 Ferrari Enzo'),
#  ('Castillo', 'Pamela', '2001 Ferrari Enzo'),
#  ('Castillo', 'Pamela', '1958 Setra Bus'),
#  ('Castillo', 'Pamela', '2002 Suzuki XREO'),
#  ('Castillo', 'Pamela', '1969 Corvair Monza'),
#  ('Castillo', 'Pamela', '1969 Corvair Monza'),
#  ('Castillo', 'Pamela', '1969 Corvair Monza'),
#  ('Castillo', 'Pamela', '1968 Dodge Charger'),
#  ('Castillo', 'Pamela', '1968 Dodge Charger'),
#  ('Castillo', 'Pamela', '1968 Dodge Charger'),
#  ('Castillo', 'Pamela', '1968 Dodge Charger'),
#  ('Castillo', 'Pamela', '1968 Dodge Charger'),
#  ('Castillo', 'Pamela', '1969 Ford Falcon'),
#  ('Castillo', 'Pamela', '1969 Ford Falcon'),
#  ('Castillo', 'Pamela', '1969 Ford Falcon'),
#  ('Castillo', 'Pamela', '1969 Ford Falcon'),
#  ('Castillo', 'Pamela', '1970 Plymouth Hemi Cuda'),
#  ('Castillo', 'Pamela', '1970 Plymouth Hemi Cuda'),
#  ('Castillo', 'Pamela', '1970 Plymouth Hemi Cuda'),
#  ('Castillo', 'Pamela', '1970 Plymouth Hemi Cuda'),
#  ('Castillo', 'Pamela', '1957 Chevy Pickup'),
#  ('Castillo', 'Pamela', '1969 Dodge Charger'),
#  ('Castillo', 'Pamela', '1969 Dodge Charger'),
#  ('Castillo', 'Pamela', '1969 Dodge Charger'),
#  ('Castillo', 'Pamela', '1969 Dodge Charger'),
#  ('Castillo', 'Pamela', '1940 Ford Pickup Truck'),
#  ('Castillo', 'Pamela', '1940 Ford Pickup Truck'),
#  ('Castillo', 'Pamela', '1993 Mazda RX-7'),
#  ('Castillo', 'Pamela', '1993 Mazda RX-7'),
#  ('Castillo', 'Pamela', '1993 Mazda RX-7'),
#  ('Castillo', 'Pamela', '1993 Mazda RX-7'),
#  ('Castillo', 'Pamela', '1937 Lincoln Berline'),
#  ('Castillo', 'Pamela', '1937 Lincoln Berline'),
#  ('Castillo', 'Pamela', '1937 Lincoln Berline'),
#  ('Castillo', 'Pamela', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Castillo', 'Pamela', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Castillo', 'Pamela', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Castillo', 'Pamela', '1965 Aston Martin DB5'),
#  ('Castillo', 'Pamela', '1965 Aston Martin DB5'),
#  ('Castillo', 'Pamela', '1965 Aston Martin DB5'),
#  ('Castillo', 'Pamela', '1980s Black Hawk Helicopter'),
#  ('Castillo', 'Pamela', '1980s Black Hawk Helicopter'),
#  ('Castillo', 'Pamela', '1980s Black Hawk Helicopter'),
#  ('Castillo', 'Pamela', '1980s Black Hawk Helicopter'),
#  ('Castillo', 'Pamela', '1980s Black Hawk Helicopter'),
#  ('Castillo', 'Pamela', '1917 Grand Touring Sedan'),
#  ('Castillo', 'Pamela', '1917 Grand Touring Sedan'),
#  ('Castillo', 'Pamela', '1948 Porsche 356-A Roadster'),
#  ('Castillo', 'Pamela', '1948 Porsche 356-A Roadster'),
#  ('Castillo', 'Pamela', '1948 Porsche 356-A Roadster'),
#  ('Castillo', 'Pamela', '1995 Honda Civic'),
#  ('Castillo', 'Pamela', '1995 Honda Civic'),
#  ('Castillo', 'Pamela', '1995 Honda Civic'),
#  ('Castillo', 'Pamela', '1995 Honda Civic'),
#  ('Castillo', 'Pamela', '1995 Honda Civic'),
#  ('Castillo', 'Pamela', '1998 Chrysler Plymouth Prowler'),
#  ('Castillo', 'Pamela', '1998 Chrysler Plymouth Prowler'),
#  ('Castillo', 'Pamela', '1911 Ford Town Car'),
#  ('Castillo', 'Pamela', '1911 Ford Town Car'),
#  ('Castillo', 'Pamela', '1964 Mercedes Tour Bus'),
#  ('Castillo', 'Pamela', '1932 Model A Ford J-Coupe'),
#  ('Castillo', 'Pamela', '1932 Model A Ford J-Coupe'),
#  ('Castillo', 'Pamela', 'P-51-D Mustang'),
#  ('Castillo', 'Pamela', 'P-51-D Mustang'),
#  ('Castillo', 'Pamela', 'P-51-D Mustang'),
#  ('Castillo', 'Pamela', 'P-51-D Mustang'),
#  ('Castillo', 'Pamela', '1928 Mercedes-Benz SSK'),
#  ('Castillo', 'Pamela', '1928 Mercedes-Benz SSK'),
#  ('Castillo', 'Pamela', '1999 Indy 500 Monte Carlo SS'),
#  ('Castillo', 'Pamela', '1999 Indy 500 Monte Carlo SS'),
#  ('Castillo', 'Pamela', '1999 Indy 500 Monte Carlo SS'),
#  ('Castillo', 'Pamela', '1999 Indy 500 Monte Carlo SS'),
#  ('Castillo', 'Pamela', '1913 Ford Model T Speedster'),
#  ('Castillo', 'Pamela', '1913 Ford Model T Speedster'),
#  ('Castillo', 'Pamela', '1934 Ford V8 Coupe'),
#  ('Castillo', 'Pamela', '1934 Ford V8 Coupe'),
#  ('Castillo', 'Pamela', '1934 Ford V8 Coupe'),
#  ('Castillo', 'Pamela', '1934 Ford V8 Coupe'),
#  ('Castillo', 'Pamela', '1934 Ford V8 Coupe'),
#  ('Castillo', 'Pamela', '1999 Yamaha Speed Boat'),
#  ('Castillo', 'Pamela', '1999 Yamaha Speed Boat'),
#  ('Castillo', 'Pamela', '1999 Yamaha Speed Boat'),
#  ('Castillo', 'Pamela', '1999 Yamaha Speed Boat'),
#  ('Castillo', 'Pamela', '1999 Yamaha Speed Boat'),
#  ('Castillo', 'Pamela', '18th Century Vintage Horse Carriage'),
#  ('Castillo', 'Pamela', '18th Century Vintage Horse Carriage'),
#  ('Castillo', 'Pamela', '18th Century Vintage Horse Carriage'),
#  ('Castillo', 'Pamela', '18th Century Vintage Horse Carriage'),
#  ('Castillo', 'Pamela', '1903 Ford Model A'),
#  ('Castillo', 'Pamela', '1903 Ford Model A'),
#  ('Castillo', 'Pamela', '1903 Ford Model A'),
#  ('Castillo', 'Pamela', '1903 Ford Model A'),
#  ('Castillo', 'Pamela', '1903 Ford Model A'),
#  ('Castillo', 'Pamela', '1992 Ferrari 360 Spider red'),
#  ('Castillo', 'Pamela', '1992 Ferrari 360 Spider red'),
#  ('Castillo', 'Pamela', '1992 Ferrari 360 Spider red'),
#  ('Castillo', 'Pamela', '1992 Ferrari 360 Spider red'),
#  ('Castillo', 'Pamela', 'Collectable Wooden Train'),
#  ('Castillo', 'Pamela', 'Collectable Wooden Train'),
#  ('Castillo', 'Pamela', 'Collectable Wooden Train'),
#  ('Castillo', 'Pamela', 'Collectable Wooden Train'),
#  ('Castillo', 'Pamela', 'Collectable Wooden Train'),
#  ('Castillo', 'Pamela', '1969 Dodge Super Bee'),
#  ('Castillo', 'Pamela', '1917 Maxwell Touring Car'),
#  ('Castillo', 'Pamela', '1917 Maxwell Touring Car'),
#  ('Castillo', 'Pamela', '1917 Maxwell Touring Car'),
#  ('Castillo', 'Pamela', '1917 Maxwell Touring Car'),
#  ('Castillo', 'Pamela', '1976 Ford Gran Torino'),
#  ('Castillo', 'Pamela', '1948 Porsche Type 356 Roadster'),
#  ('Castillo', 'Pamela', '1948 Porsche Type 356 Roadster'),
#  ('Castillo', 'Pamela', '1948 Porsche Type 356 Roadster'),
#  ('Castillo', 'Pamela', '1948 Porsche Type 356 Roadster'),
#  ('Castillo', 'Pamela', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Castillo', 'Pamela', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Castillo', 'Pamela', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Castillo', 'Pamela', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Castillo', 'Pamela', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Castillo', 'Pamela', '1970 Triumph Spitfire'),
#  ('Castillo', 'Pamela', '1970 Triumph Spitfire'),
#  ('Castillo', 'Pamela', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Castillo', 'Pamela', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Castillo', 'Pamela', '1904 Buick Runabout'),
#  ('Castillo', 'Pamela', '1904 Buick Runabout'),
#  ('Castillo', 'Pamela', '1904 Buick Runabout'),
#  ('Castillo', 'Pamela', '1904 Buick Runabout'),
#  ('Castillo', 'Pamela', '1940s Ford truck'),
#  ('Castillo', 'Pamela', '1939 Cadillac Limousine'),
#  ('Castillo', 'Pamela', '1957 Corvette Convertible'),
#  ('Castillo', 'Pamela', '1957 Ford Thunderbird'),
#  ('Castillo', 'Pamela', '1957 Ford Thunderbird'),
#  ('Castillo', 'Pamela', '1970 Chevy Chevelle SS 454'),
#  ('Castillo', 'Pamela', '1970 Dodge Coronet'),
#  ('Castillo', 'Pamela', '1970 Dodge Coronet'),
#  ('Castillo', 'Pamela', '1966 Shelby Cobra 427 S/C'),
#  ('Castillo', 'Pamela', '1966 Shelby Cobra 427 S/C'),
#  ('Castillo', 'Pamela', '1928 British Royal Navy Airplane'),
#  ('Castillo', 'Pamela', '1928 British Royal Navy Airplane'),
#  ('Castillo', 'Pamela', '1928 British Royal Navy Airplane'),
#  ('Castillo', 'Pamela', '1928 British Royal Navy Airplane'),
#  ('Castillo', 'Pamela', '1939 Chevrolet Deluxe Coupe'),
#  ('Castillo', 'Pamela', '1939 Chevrolet Deluxe Coupe'),
#  ('Castillo', 'Pamela', '1960 BSA Gold Star DBD34'),
#  ('Castillo', 'Pamela', '18th century schooner'),
#  ('Castillo', 'Pamela', '18th century schooner'),
#  ('Castillo', 'Pamela', '18th century schooner'),
#  ('Castillo', 'Pamela', '18th century schooner'),
#  ('Castillo', 'Pamela', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Castillo', 'Pamela', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Castillo', 'Pamela', '1982 Ducati 900 Monster'),
#  ('Castillo', 'Pamela', '1949 Jaguar XK 120'),
#  ('Castillo', 'Pamela', '1958 Chevy Corvette Limited Edition'),
#  ('Castillo', 'Pamela', '1900s Vintage Bi-Plane'),
#  ('Castillo', 'Pamela', '1900s Vintage Bi-Plane'),
#  ('Castillo', 'Pamela', '1900s Vintage Bi-Plane'),
#  ('Castillo', 'Pamela', '1952 Citroen-15CV'),
#  ('Castillo', 'Pamela', '1952 Citroen-15CV'),
#  ('Castillo', 'Pamela', '1982 Lamborghini Diablo'),
#  ('Castillo', 'Pamela', '1982 Lamborghini Diablo'),
#  ('Castillo', 'Pamela', '1912 Ford Model T Delivery Wagon'),
#  ('Castillo', 'Pamela', '1912 Ford Model T Delivery Wagon'),
#  ('Castillo', 'Pamela', '1912 Ford Model T Delivery Wagon'),
#  ('Castillo', 'Pamela', '1969 Chevrolet Camaro Z28'),
#  ('Castillo', 'Pamela', '1971 Alpine Renault 1600s'),
#  ('Castillo', 'Pamela', '1971 Alpine Renault 1600s'),
#  ('Castillo', 'Pamela', '1971 Alpine Renault 1600s'),
#  ('Castillo', 'Pamela', '1937 Horch 930V Limousine'),
#  ('Castillo', 'Pamela', '1937 Horch 930V Limousine'),
#  ('Castillo', 'Pamela', '1937 Horch 930V Limousine'),
#  ('Castillo', 'Pamela', '2002 Chevy Corvette'),
#  ('Castillo', 'Pamela', '1940 Ford Delivery Sedan'),
#  ('Castillo', 'Pamela', '1940 Ford Delivery Sedan'),
#  ('Castillo', 'Pamela', '1940 Ford Delivery Sedan'),
#  ('Castillo', 'Pamela', '1956 Porsche 356A Coupe'),
#  ('Castillo', 'Pamela', '1956 Porsche 356A Coupe'),
#  ('Castillo', 'Pamela', '1956 Porsche 356A Coupe'),
#  ('Castillo', 'Pamela', 'Corsair F4U ( Bird Cage)'),
#  ('Castillo', 'Pamela', 'Corsair F4U ( Bird Cage)'),
#  ('Castillo', 'Pamela', 'Corsair F4U ( Bird Cage)'),
#  ('Castillo', 'Pamela', 'Corsair F4U ( Bird Cage)'),
#  ('Castillo', 'Pamela', '1936 Mercedes Benz 500k Roadster'),
#  ('Castillo', 'Pamela', '1936 Mercedes Benz 500k Roadster'),
#  ('Castillo', 'Pamela', '1992 Porsche Cayenne Turbo Silver'),
#  ('Castillo', 'Pamela', '1992 Porsche Cayenne Turbo Silver'),
#  ('Castillo', 'Pamela', '1936 Chrysler Airflow'),
#  ('Castillo', 'Pamela', '1936 Chrysler Airflow'),
#  ('Castillo', 'Pamela', '1936 Chrysler Airflow'),
#  ('Castillo', 'Pamela', '1936 Chrysler Airflow'),
#  ('Castillo', 'Pamela', '1900s Vintage Tri-Plane'),
#  ('Castillo', 'Pamela', '1900s Vintage Tri-Plane'),
#  ('Castillo', 'Pamela', '1900s Vintage Tri-Plane'),
#  ('Castillo', 'Pamela', '1900s Vintage Tri-Plane'),
#  ('Castillo', 'Pamela', '1961 Chevrolet Impala'),
#  ('Castillo', 'Pamela', '1980’s GM Manhattan Express'),
#  ('Castillo', 'Pamela', '1997 BMW F650 ST'),
#  ('Castillo', 'Pamela', '1997 BMW F650 ST'),
#  ('Castillo', 'Pamela', "1950's Chicago Surface Lines Streetcar"),
#  ('Castillo', 'Pamela', "1950's Chicago Surface Lines Streetcar"),
#  ('Castillo', 'Pamela', "1950's Chicago Surface Lines Streetcar"),
#  ('Castillo', 'Pamela', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Castillo', 'Pamela', '1928 Ford Phaeton Deluxe'),
#  ('Castillo', 'Pamela', '1928 Ford Phaeton Deluxe'),
#  ('Castillo', 'Pamela', '1928 Ford Phaeton Deluxe'),
#  ('Castillo', 'Pamela', '1928 Ford Phaeton Deluxe'),
#  ('Castillo', 'Pamela', '1928 Ford Phaeton Deluxe'),
#  ('Castillo', 'Pamela', '1974 Ducati 350 Mk3 Desmo'),
#  ('Castillo', 'Pamela', '1930 Buick Marquette Phaeton'),
#  ('Castillo', 'Pamela', '1930 Buick Marquette Phaeton'),
#  ('Castillo', 'Pamela', '1930 Buick Marquette Phaeton'),
#  ('Castillo', 'Pamela', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Castillo', 'Pamela', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Castillo', 'Pamela', '1962 City of Detroit Streetcar'),
#  ('Castillo', 'Pamela', '1962 City of Detroit Streetcar'),
#  ('Castillo', 'Pamela', '2002 Yamaha YZR M1'),
#  ('Castillo', 'Pamela', 'The Schooner Bluenose'),
#  ('Castillo', 'Pamela', 'The Schooner Bluenose'),
#  ('Castillo', 'Pamela', 'The Schooner Bluenose'),
#  ('Castillo', 'Pamela', 'American Airlines: B767-300'),
#  ('Castillo', 'Pamela', 'American Airlines: B767-300'),
#  ('Castillo', 'Pamela', 'American Airlines: B767-300'),
#  ('Castillo', 'Pamela', 'The Mayflower'),
#  ('Castillo', 'Pamela', 'The Mayflower'),
#  ('Castillo', 'Pamela', 'The Mayflower'),
#  ('Castillo', 'Pamela', 'The Mayflower'),
#  ('Castillo', 'Pamela', 'The Mayflower'),
#  ('Castillo', 'Pamela', 'The Mayflower'),
#  ('Castillo', 'Pamela', 'HMS Bounty'),
#  ('Castillo', 'Pamela', 'HMS Bounty'),
#  ('Castillo', 'Pamela', 'HMS Bounty'),
#  ('Castillo', 'Pamela', 'America West Airlines B757-200'),
#  ('Castillo', 'Pamela', 'America West Airlines B757-200'),
#  ('Castillo', 'Pamela', 'America West Airlines B757-200'),
#  ('Castillo', 'Pamela', 'The USS Constitution Ship'),
#  ('Castillo', 'Pamela', 'The USS Constitution Ship'),
#  ('Castillo', 'Pamela', 'The USS Constitution Ship'),
#  ('Castillo', 'Pamela', 'The USS Constitution Ship'),
#  ('Castillo', 'Pamela', '1982 Camaro Z28'),
#  ('Castillo', 'Pamela', 'ATA: B757-300'),
#  ('Castillo', 'Pamela', 'ATA: B757-300'),
#  ('Castillo', 'Pamela', 'ATA: B757-300'),
#  ('Castillo', 'Pamela', 'ATA: B757-300'),
#  ('Castillo', 'Pamela', 'F/A 18 Hornet 1/72'),
#  ('Castillo', 'Pamela', 'F/A 18 Hornet 1/72'),
#  ('Castillo', 'Pamela', 'F/A 18 Hornet 1/72'),
#  ('Castillo', 'Pamela', 'F/A 18 Hornet 1/72'),
#  ('Castillo', 'Pamela', 'The Titanic'),
#  ('Castillo', 'Pamela', 'The Titanic'),
#  ('Castillo', 'Pamela', 'The Titanic'),
#  ('Castillo', 'Pamela', 'The Queen Mary'),
#  ('Castillo', 'Pamela', 'The Queen Mary'),
#  ('Castillo', 'Pamela', 'The Queen Mary'),
#  ('Castillo', 'Pamela', 'American Airlines: MD-11S'),
#  ('Castillo', 'Pamela', 'American Airlines: MD-11S'),
#  ('Castillo', 'Pamela', 'American Airlines: MD-11S'),
#  ('Castillo', 'Pamela', 'American Airlines: MD-11S'),
#  ('Castillo', 'Pamela', 'Boeing X-32A JSF'),
#  ('Castillo', 'Pamela', 'Boeing X-32A JSF'),
#  ('Castillo', 'Pamela', 'Pont Yacht'),
#  ('Castillo', 'Pamela', 'Pont Yacht'),
#  ('Castillo', 'Pamela', 'Pont Yacht'),
#  ('Castillo', 'Pamela', 'Pont Yacht'),
#  ('Firrelli', 'Julie', '1952 Alpine Renault 1300'),
#  ('Firrelli', 'Julie', '1952 Alpine Renault 1300'),
#  ('Firrelli', 'Julie', '1952 Alpine Renault 1300'),
#  ('Firrelli', 'Julie', '1972 Alfa Romeo GTA'),
#  ('Firrelli', 'Julie', '1972 Alfa Romeo GTA'),
#  ('Firrelli', 'Julie', '1962 LanciaA Delta 16V'),
#  ('Firrelli', 'Julie', '1962 LanciaA Delta 16V'),
#  ('Firrelli', 'Julie', '1968 Ford Mustang'),
#  ('Firrelli', 'Julie', '1968 Ford Mustang'),
#  ('Firrelli', 'Julie', '2001 Ferrari Enzo'),
#  ('Firrelli', 'Julie', '1958 Setra Bus'),
#  ('Firrelli', 'Julie', '2002 Suzuki XREO'),
#  ('Firrelli', 'Julie', '1969 Corvair Monza'),
#  ('Firrelli', 'Julie', '1968 Dodge Charger'),
#  ('Firrelli', 'Julie', '1968 Dodge Charger'),
#  ('Firrelli', 'Julie', '1969 Ford Falcon'),
#  ('Firrelli', 'Julie', '1970 Plymouth Hemi Cuda'),
#  ('Firrelli', 'Julie', '1970 Plymouth Hemi Cuda'),
#  ('Firrelli', 'Julie', '1957 Chevy Pickup'),
#  ('Firrelli', 'Julie', '1969 Dodge Charger'),
#  ('Firrelli', 'Julie', '1940 Ford Pickup Truck'),
#  ('Firrelli', 'Julie', '1940 Ford Pickup Truck'),
#  ('Firrelli', 'Julie', '1993 Mazda RX-7'),
#  ('Firrelli', 'Julie', '1937 Lincoln Berline'),
#  ('Firrelli', 'Julie', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Firrelli', 'Julie', '1980s Black Hawk Helicopter'),
#  ('Firrelli', 'Julie', '1980s Black Hawk Helicopter'),
#  ('Firrelli', 'Julie', '1980s Black Hawk Helicopter'),
#  ('Firrelli', 'Julie', '1948 Porsche 356-A Roadster'),
#  ('Firrelli', 'Julie', '1998 Chrysler Plymouth Prowler'),
#  ('Firrelli', 'Julie', '1964 Mercedes Tour Bus'),
#  ('Firrelli', 'Julie', '1932 Model A Ford J-Coupe'),
#  ('Firrelli', 'Julie', '1926 Ford Fire Engine'),
#  ('Firrelli', 'Julie', '1913 Ford Model T Speedster'),
#  ('Firrelli', 'Julie', '1913 Ford Model T Speedster'),
#  ('Firrelli', 'Julie', '1913 Ford Model T Speedster'),
#  ('Firrelli', 'Julie', '1934 Ford V8 Coupe'),
#  ('Firrelli', 'Julie', '1934 Ford V8 Coupe'),
#  ('Firrelli', 'Julie', '1934 Ford V8 Coupe'),
#  ('Firrelli', 'Julie', '1999 Yamaha Speed Boat'),
#  ('Firrelli', 'Julie', '1999 Yamaha Speed Boat'),
#  ('Firrelli', 'Julie', '18th Century Vintage Horse Carriage'),
#  ('Firrelli', 'Julie', '18th Century Vintage Horse Carriage'),
#  ('Firrelli', 'Julie', '18th Century Vintage Horse Carriage'),
#  ('Firrelli', 'Julie', '1903 Ford Model A'),
#  ('Firrelli', 'Julie', '1992 Ferrari 360 Spider red'),
#  ('Firrelli', 'Julie', 'Collectable Wooden Train'),
#  ('Firrelli', 'Julie', '1969 Dodge Super Bee'),
#  ('Firrelli', 'Julie', '1969 Dodge Super Bee'),
#  ('Firrelli', 'Julie', '1917 Maxwell Touring Car'),
#  ('Firrelli', 'Julie', '1976 Ford Gran Torino'),
#  ('Firrelli', 'Julie', '1976 Ford Gran Torino'),
#  ('Firrelli', 'Julie', '1957 Vespa GS150'),
#  ('Firrelli', 'Julie', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Firrelli', 'Julie', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Firrelli', 'Julie', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Firrelli', 'Julie', '1970 Triumph Spitfire'),
#  ('Firrelli', 'Julie', '1970 Triumph Spitfire'),
#  ('Firrelli', 'Julie', '1904 Buick Runabout'),
#  ('Firrelli', 'Julie', '1940s Ford truck'),
#  ('Firrelli', 'Julie', '1940s Ford truck'),
#  ('Firrelli', 'Julie', '1939 Cadillac Limousine'),
#  ('Firrelli', 'Julie', '1957 Corvette Convertible'),
#  ('Firrelli', 'Julie', '1970 Dodge Coronet'),
#  ('Firrelli', 'Julie', '1939 Chevrolet Deluxe Coupe'),
#  ('Firrelli', 'Julie', '18th century schooner'),
#  ('Firrelli', 'Julie', '1962 Volkswagen Microbus'),
#  ('Firrelli', 'Julie', '1982 Ducati 900 Monster'),
#  ('Firrelli', 'Julie', '1958 Chevy Corvette Limited Edition'),
#  ('Firrelli', 'Julie', '1900s Vintage Bi-Plane'),
#  ('Firrelli', 'Julie', '1900s Vintage Bi-Plane'),
#  ('Firrelli', 'Julie', '1900s Vintage Bi-Plane'),
#  ('Firrelli', 'Julie', '1900s Vintage Bi-Plane'),
#  ('Firrelli', 'Julie', '1982 Lamborghini Diablo'),
#  ('Firrelli', 'Julie', '1912 Ford Model T Delivery Wagon'),
#  ('Firrelli', 'Julie', '1971 Alpine Renault 1600s'),
#  ('Firrelli', 'Julie', '1971 Alpine Renault 1600s'),
#  ('Firrelli', 'Julie', '1937 Horch 930V Limousine'),
#  ('Firrelli', 'Julie', '1937 Horch 930V Limousine'),
#  ('Firrelli', 'Julie', '1937 Horch 930V Limousine'),
#  ('Firrelli', 'Julie', '1937 Horch 930V Limousine'),
#  ('Firrelli', 'Julie', '1940 Ford Delivery Sedan'),
#  ('Firrelli', 'Julie', '1940 Ford Delivery Sedan'),
#  ('Firrelli', 'Julie', '1956 Porsche 356A Coupe'),
#  ('Firrelli', 'Julie', 'Corsair F4U ( Bird Cage)'),
#  ('Firrelli', 'Julie', '1992 Porsche Cayenne Turbo Silver'),
#  ('Firrelli', 'Julie', '1936 Chrysler Airflow'),
#  ('Firrelli', 'Julie', '1936 Chrysler Airflow'),
#  ('Firrelli', 'Julie', '1936 Chrysler Airflow'),
#  ('Firrelli', 'Julie', '1961 Chevrolet Impala'),
#  ('Firrelli', 'Julie', '1961 Chevrolet Impala'),
#  ('Firrelli', 'Julie', '1980’s GM Manhattan Express'),
#  ('Firrelli', 'Julie', '1982 Ducati 996 R'),
#  ('Firrelli', 'Julie', '1954 Greyhound Scenicruiser'),
#  ('Firrelli', 'Julie', "1950's Chicago Surface Lines Streetcar"),
#  ('Firrelli', 'Julie', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Firrelli', 'Julie', '1974 Ducati 350 Mk3 Desmo'),
#  ('Firrelli', 'Julie', '1974 Ducati 350 Mk3 Desmo'),
#  ('Firrelli', 'Julie', '1930 Buick Marquette Phaeton'),
#  ('Firrelli', 'Julie', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Firrelli', 'Julie', '1962 City of Detroit Streetcar'),
#  ('Firrelli', 'Julie', '2002 Yamaha YZR M1'),
#  ('Firrelli', 'Julie', '2002 Yamaha YZR M1'),
#  ('Firrelli', 'Julie', 'The Schooner Bluenose'),
#  ('Firrelli', 'Julie', 'American Airlines: B767-300'),
#  ('Firrelli', 'Julie', 'The Mayflower'),
#  ('Firrelli', 'Julie', 'HMS Bounty'),
#  ('Firrelli', 'Julie', 'HMS Bounty'),
#  ('Firrelli', 'Julie', 'HMS Bounty'),
#  ('Firrelli', 'Julie', 'HMS Bounty'),
#  ('Firrelli', 'Julie', 'America West Airlines B757-200'),
#  ('Firrelli', 'Julie', 'The USS Constitution Ship'),
#  ('Firrelli', 'Julie', 'The USS Constitution Ship'),
#  ('Firrelli', 'Julie', '1982 Camaro Z28'),
#  ('Firrelli', 'Julie', 'F/A 18 Hornet 1/72'),
#  ('Firrelli', 'Julie', 'The Titanic'),
#  ('Firrelli', 'Julie', 'The Queen Mary'),
#  ('Firrelli', 'Julie', 'The Queen Mary'),
#  ('Firrelli', 'Julie', 'American Airlines: MD-11S'),
#  ('Firrelli', 'Julie', 'Boeing X-32A JSF'),
#  ('Firrelli', 'Julie', 'Boeing X-32A JSF'),
#  ('Firrelli', 'Julie', 'Boeing X-32A JSF'),
#  ('Firrelli', 'Julie', 'Boeing X-32A JSF'),
#  ('Firrelli', 'Julie', 'Pont Yacht'),
#  ('Fixter', 'Andy', '1969 Harley Davidson Ultimate Chopper'),
#  ('Fixter', 'Andy', '1969 Harley Davidson Ultimate Chopper'),
#  ('Fixter', 'Andy', '1952 Alpine Renault 1300'),
#  ('Fixter', 'Andy', '1952 Alpine Renault 1300'),
#  ('Fixter', 'Andy', '1952 Alpine Renault 1300'),
#  ('Fixter', 'Andy', '1952 Alpine Renault 1300'),
#  ('Fixter', 'Andy', '1996 Moto Guzzi 1100i'),
#  ('Fixter', 'Andy', '1996 Moto Guzzi 1100i'),
#  ('Fixter', 'Andy', '1996 Moto Guzzi 1100i'),
#  ('Fixter', 'Andy', '1996 Moto Guzzi 1100i'),
#  ('Fixter', 'Andy', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Fixter', 'Andy', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Fixter', 'Andy', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Fixter', 'Andy', '1962 LanciaA Delta 16V'),
#  ('Fixter', 'Andy', '1962 LanciaA Delta 16V'),
#  ('Fixter', 'Andy', '1962 LanciaA Delta 16V'),
#  ('Fixter', 'Andy', '1962 LanciaA Delta 16V'),
#  ('Fixter', 'Andy', '1968 Ford Mustang'),
#  ('Fixter', 'Andy', '1958 Setra Bus'),
#  ('Fixter', 'Andy', '1958 Setra Bus'),
#  ('Fixter', 'Andy', '1958 Setra Bus'),
#  ('Fixter', 'Andy', '1958 Setra Bus'),
#  ('Fixter', 'Andy', '1958 Setra Bus'),
#  ('Fixter', 'Andy', '2002 Suzuki XREO'),
#  ('Fixter', 'Andy', '1970 Plymouth Hemi Cuda'),
#  ('Fixter', 'Andy', '1940 Ford Pickup Truck'),
#  ('Fixter', 'Andy', '1940 Ford Pickup Truck'),
#  ('Fixter', 'Andy', '1940 Ford Pickup Truck'),
#  ('Fixter', 'Andy', '1940 Ford Pickup Truck'),
#  ('Fixter', 'Andy', '1940 Ford Pickup Truck'),
#  ('Fixter', 'Andy', '1993 Mazda RX-7'),
#  ('Fixter', 'Andy', '1993 Mazda RX-7'),
#  ('Fixter', 'Andy', '1937 Lincoln Berline'),
#  ('Fixter', 'Andy', '1937 Lincoln Berline'),
#  ('Fixter', 'Andy', '1937 Lincoln Berline'),
#  ('Fixter', 'Andy', '1937 Lincoln Berline'),
#  ('Fixter', 'Andy', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Fixter', 'Andy', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Fixter', 'Andy', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Fixter', 'Andy', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Fixter', 'Andy', '1965 Aston Martin DB5'),
#  ('Fixter', 'Andy', '1917 Grand Touring Sedan'),
#  ('Fixter', 'Andy', '1917 Grand Touring Sedan'),
#  ('Fixter', 'Andy', '1948 Porsche 356-A Roadster'),
#  ('Fixter', 'Andy', '1995 Honda Civic'),
#  ('Fixter', 'Andy', '1995 Honda Civic'),
#  ('Fixter', 'Andy', '1911 Ford Town Car'),
#  ('Fixter', 'Andy', '1911 Ford Town Car'),
#  ('Fixter', 'Andy', '1964 Mercedes Tour Bus'),
#  ('Fixter', 'Andy', '1932 Model A Ford J-Coupe'),
#  ('Fixter', 'Andy', '1932 Model A Ford J-Coupe'),
#  ('Fixter', 'Andy', '1926 Ford Fire Engine'),
#  ('Fixter', 'Andy', '1926 Ford Fire Engine'),
#  ('Fixter', 'Andy', '1926 Ford Fire Engine'),
#  ('Fixter', 'Andy', 'P-51-D Mustang'),
#  ('Fixter', 'Andy', 'P-51-D Mustang'),
#  ('Fixter', 'Andy', 'P-51-D Mustang'),
#  ('Fixter', 'Andy', '1936 Harley Davidson El Knucklehead'),
#  ('Fixter', 'Andy', '1936 Harley Davidson El Knucklehead'),
#  ('Fixter', 'Andy', '1936 Harley Davidson El Knucklehead'),
#  ('Fixter', 'Andy', '1928 Mercedes-Benz SSK'),
#  ('Fixter', 'Andy', '1928 Mercedes-Benz SSK'),
#  ('Fixter', 'Andy', '1928 Mercedes-Benz SSK'),
#  ('Fixter', 'Andy', '1928 Mercedes-Benz SSK'),
#  ('Fixter', 'Andy', '1999 Indy 500 Monte Carlo SS'),
#  ('Fixter', 'Andy', '1913 Ford Model T Speedster'),
#  ('Fixter', 'Andy', '1913 Ford Model T Speedster'),
#  ('Fixter', 'Andy', '1913 Ford Model T Speedster'),
#  ('Fixter', 'Andy', '1913 Ford Model T Speedster'),
#  ('Fixter', 'Andy', '1913 Ford Model T Speedster'),
#  ('Fixter', 'Andy', '1913 Ford Model T Speedster'),
#  ('Fixter', 'Andy', '1934 Ford V8 Coupe'),
#  ('Fixter', 'Andy', '1934 Ford V8 Coupe'),
#  ('Fixter', 'Andy', '1934 Ford V8 Coupe'),
#  ('Fixter', 'Andy', '18th Century Vintage Horse Carriage'),
#  ('Fixter', 'Andy', '18th Century Vintage Horse Carriage'),
#  ('Fixter', 'Andy', '18th Century Vintage Horse Carriage'),
#  ('Fixter', 'Andy', '18th Century Vintage Horse Carriage'),
#  ('Fixter', 'Andy', '1992 Ferrari 360 Spider red'),
#  ('Fixter', 'Andy', '1992 Ferrari 360 Spider red'),
#  ('Fixter', 'Andy', '1992 Ferrari 360 Spider red'),
#  ('Fixter', 'Andy', '1969 Dodge Super Bee'),
#  ('Fixter', 'Andy', '1969 Dodge Super Bee'),
#  ('Fixter', 'Andy', '1969 Dodge Super Bee'),
#  ('Fixter', 'Andy', '1917 Maxwell Touring Car'),
#  ('Fixter', 'Andy', '1917 Maxwell Touring Car'),
#  ('Fixter', 'Andy', '1917 Maxwell Touring Car'),
#  ('Fixter', 'Andy', '1976 Ford Gran Torino'),
#  ('Fixter', 'Andy', '1976 Ford Gran Torino'),
#  ('Fixter', 'Andy', '1976 Ford Gran Torino'),
#  ('Fixter', 'Andy', '1948 Porsche Type 356 Roadster'),
#  ('Fixter', 'Andy', '1957 Vespa GS150'),
#  ('Fixter', 'Andy', '1957 Vespa GS150'),
#  ('Fixter', 'Andy', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Fixter', 'Andy', '1970 Triumph Spitfire'),
#  ('Fixter', 'Andy', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Fixter', 'Andy', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Fixter', 'Andy', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Fixter', 'Andy', '1940s Ford truck'),
#  ('Fixter', 'Andy', '1940s Ford truck'),
#  ('Fixter', 'Andy', '1940s Ford truck'),
#  ('Fixter', 'Andy', '1939 Cadillac Limousine'),
#  ('Fixter', 'Andy', '1939 Cadillac Limousine'),
#  ('Fixter', 'Andy', '1939 Cadillac Limousine'),
#  ('Fixter', 'Andy', '1957 Corvette Convertible'),
#  ('Fixter', 'Andy', '1957 Corvette Convertible'),
#  ('Fixter', 'Andy', '1957 Ford Thunderbird'),
#  ('Fixter', 'Andy', '1957 Ford Thunderbird'),
#  ('Fixter', 'Andy', '1957 Ford Thunderbird'),
#  ('Fixter', 'Andy', '1970 Chevy Chevelle SS 454'),
#  ('Fixter', 'Andy', '1970 Chevy Chevelle SS 454'),
#  ('Fixter', 'Andy', '1970 Dodge Coronet'),
#  ('Fixter', 'Andy', '1997 BMW R 1100 S'),
#  ('Fixter', 'Andy', '1997 BMW R 1100 S'),
#  ('Fixter', 'Andy', '1997 BMW R 1100 S'),
#  ('Fixter', 'Andy', '1966 Shelby Cobra 427 S/C'),
#  ('Fixter', 'Andy', '1966 Shelby Cobra 427 S/C'),
#  ('Fixter', 'Andy', '1928 British Royal Navy Airplane'),
#  ('Fixter', 'Andy', '1928 British Royal Navy Airplane'),
#  ('Fixter', 'Andy', '1928 British Royal Navy Airplane'),
#  ('Fixter', 'Andy', '1939 Chevrolet Deluxe Coupe'),
#  ('Fixter', 'Andy', '1939 Chevrolet Deluxe Coupe'),
#  ('Fixter', 'Andy', '1939 Chevrolet Deluxe Coupe'),
#  ('Fixter', 'Andy', '1960 BSA Gold Star DBD34'),
#  ('Fixter', 'Andy', '1960 BSA Gold Star DBD34'),
#  ('Fixter', 'Andy', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Fixter', 'Andy', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Fixter', 'Andy', '1982 Ducati 900 Monster'),
#  ('Fixter', 'Andy', '1949 Jaguar XK 120'),
#  ('Fixter', 'Andy', '1949 Jaguar XK 120'),
#  ('Fixter', 'Andy', '1900s Vintage Bi-Plane'),
#  ('Fixter', 'Andy', '1952 Citroen-15CV'),
#  ('Fixter', 'Andy', '1952 Citroen-15CV'),
#  ('Fixter', 'Andy', '1982 Lamborghini Diablo'),
#  ('Fixter', 'Andy', '1969 Chevrolet Camaro Z28'),
#  ('Fixter', 'Andy', '1969 Chevrolet Camaro Z28'),
#  ('Fixter', 'Andy', '1971 Alpine Renault 1600s'),
#  ('Fixter', 'Andy', '1971 Alpine Renault 1600s'),
#  ('Fixter', 'Andy', '1937 Horch 930V Limousine'),
#  ('Fixter', 'Andy', '1937 Horch 930V Limousine'),
#  ('Fixter', 'Andy', '2002 Chevy Corvette'),
#  ('Fixter', 'Andy', '2002 Chevy Corvette'),
#  ('Fixter', 'Andy', '1956 Porsche 356A Coupe'),
#  ('Fixter', 'Andy', 'Corsair F4U ( Bird Cage)'),
#  ('Fixter', 'Andy', '1936 Mercedes Benz 500k Roadster'),
#  ('Fixter', 'Andy', '1936 Mercedes Benz 500k Roadster'),
#  ('Fixter', 'Andy', '1992 Porsche Cayenne Turbo Silver'),
#  ('Fixter', 'Andy', '1936 Chrysler Airflow'),
#  ('Fixter', 'Andy', '1936 Chrysler Airflow'),
#  ('Fixter', 'Andy', '1900s Vintage Tri-Plane'),
#  ('Fixter', 'Andy', '1900s Vintage Tri-Plane'),
#  ('Fixter', 'Andy', '1900s Vintage Tri-Plane'),
#  ('Fixter', 'Andy', '1961 Chevrolet Impala'),
#  ('Fixter', 'Andy', '1980’s GM Manhattan Express'),
#  ('Fixter', 'Andy', '1997 BMW F650 ST'),
#  ('Fixter', 'Andy', '1997 BMW F650 ST'),
#  ('Fixter', 'Andy', '1982 Ducati 996 R'),
#  ('Fixter', 'Andy', "1950's Chicago Surface Lines Streetcar"),
#  ('Fixter', 'Andy', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Fixter', 'Andy', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Fixter', 'Andy', '1928 Ford Phaeton Deluxe'),
#  ('Fixter', 'Andy', '1928 Ford Phaeton Deluxe'),
#  ('Fixter', 'Andy', '1928 Ford Phaeton Deluxe'),
#  ('Fixter', 'Andy', '1974 Ducati 350 Mk3 Desmo'),
#  ('Fixter', 'Andy', '1930 Buick Marquette Phaeton'),
#  ('Fixter', 'Andy', '1930 Buick Marquette Phaeton'),
#  ('Fixter', 'Andy', '1930 Buick Marquette Phaeton'),
#  ('Fixter', 'Andy', '2002 Yamaha YZR M1'),
#  ('Fixter', 'Andy', 'American Airlines: B767-300'),
#  ('Fixter', 'Andy', 'American Airlines: B767-300'),
#  ('Fixter', 'Andy', 'American Airlines: B767-300'),
#  ('Fixter', 'Andy', 'HMS Bounty'),
#  ('Fixter', 'Andy', 'HMS Bounty'),
#  ('Fixter', 'Andy', 'America West Airlines B757-200'),
#  ('Fixter', 'Andy', 'America West Airlines B757-200'),
#  ('Fixter', 'Andy', '1982 Camaro Z28'),
#  ('Fixter', 'Andy', 'ATA: B757-300'),
#  ('Fixter', 'Andy', 'ATA: B757-300'),
#  ('Fixter', 'Andy', 'ATA: B757-300'),
#  ('Fixter', 'Andy', 'F/A 18 Hornet 1/72'),
#  ('Fixter', 'Andy', 'F/A 18 Hornet 1/72'),
#  ('Fixter', 'Andy', 'F/A 18 Hornet 1/72'),
#  ('Fixter', 'Andy', 'American Airlines: MD-11S'),
#  ('Fixter', 'Andy', 'Boeing X-32A JSF'),
#  ('Fixter', 'Andy', 'Boeing X-32A JSF'),
#  ('Gerard', 'Martin', '1952 Alpine Renault 1300'),
#  ('Gerard', 'Martin', '1972 Alfa Romeo GTA'),
#  ('Gerard', 'Martin', '1962 LanciaA Delta 16V'),
#  ('Gerard', 'Martin', '1968 Ford Mustang'),
#  ('Gerard', 'Martin', '1968 Ford Mustang'),
#  ('Gerard', 'Martin', '2001 Ferrari Enzo'),
#  ...]

# %% [markdown]
# ## Level Up: Display the Number of Products each Employee Has sold

# %%
cur.execute("""SELECT lastName, firstName, COUNT(productName) as sum_products FROM products p
                JOIN orderdetails od
                ON p.productcode = od.productcode
                JOIN orders o
                ON od.orderNumber = o.orderNumber
                JOIN customers c
                ON o.customerNumber = c.customerNumber
                JOIN employees e
                ON c.salesRepEmployeeNumber = e.employeeNumber
                GROUP BY lastName
                ORDER BY sum_products DESC;""").fetchall()
                
# df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
# df.columns = [i[0] for i in cur.description]
# df.head()
# Out:
# [('Hernandez', 'Gerard', 396),
#  ('Jennings', 'Leslie', 331),
#  ('Castillo', 'Pamela', 272),
#  ('Bott', 'Larry', 236),
#  ('Jones', 'Barry', 220),
#  ('Vanauf', 'George', 211),
#  ('Fixter', 'Andy', 185),
#  ('Marsh', 'Peter', 185),
#  ('Bondur', 'Loui', 177),
#  ('Patterson', 'Steve', 152),
#  ('Tseng', 'Foon Yue', 142),
#  ('Nishi', 'Mami', 137),
#  ('Firrelli', 'Julie', 124),
#  ('Gerard', 'Martin', 114),
#  ('Thompson', 'Leslie', 114)]

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use Join statements, along with leveraging your foreign keys knowledge!
